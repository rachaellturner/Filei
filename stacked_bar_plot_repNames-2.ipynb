# %%
import numpy as np
import matplotlib.pyplot as plt

chromosome_list=["chr1","chr2","chr3", "chr4", "chr5", "chr6", "chr7", "chr8", "chr9", "chr10", "chr11", "chr12", "chr13", "chr14", "chr15", "chr16", "chr17", "chr18", "chr19", "chr20", "chr21", "chr22", "chrX", "chrY"]
from collections import Counter

ORF0_list = [('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA4', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1P1', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA6', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1PA3', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA4', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA4', 'chr9'), ('L1HS', 'chr9'), ('L1PA2', 'chr9'), ('L1PA4', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chr9'), ('L1PA7', 'chr9'), ('L1PA2', 'chr9'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrY'), ('L1HS', 'chrY'), ('L1PA2', 'chrY'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA3', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1PA4', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1P1', 'chr11'), ('L1PA2', 'chr11'), ('L1PA4', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr12'), ('L1HS', 'chr12'), ('L1PA3', 'chr12'), ('L1HS', 'chr12'), ('L1PA2', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA3', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr13'), ('L1HS', 'chr13'), ('L1PA2', 'chr13'), ('L1PA2', 'chr13'), ('L1PA2', 'chr13'), ('L1PA2', 'chr13'), ('L1HS', 'chr13'), ('L1HS', 'chr13'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1PA3', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1PA2', 'chr17'), ('L1PA2', 'chr17'), ('L1PA2', 'chr17'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr19'), ('L1PA2', 'chr20'), ('L1PA2', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr20'), ('L1PA3', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr22'), ('L1HS', 'chr22'), ('L1HS', 'chr22'), ('L1HS', 'chr2_GL383521v1_alt'), ('L1HS', 'chr2_GL582966v2_alt'), ('L1HS', 'chr6_GL000253v2_alt'), ('L1PA2', 'chr8_KI270900v1_alt'), ('L1PA2', 'chr8_KI270926v1_alt'), ('L1PA4', 'chr9_GL383540v1_alt'), ('L1HS', 'chr9_GL383541v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1HS', 'chr16_KI270853v1_alt'), ('L1HS', 'chr17_GL383565v1_alt'), ('L1HS', 'chr17_GL383565v1_alt'), ('L1HS', 'chr18_GL383567v1_alt'), ('L1HS', 'chr18_GL383568v1_alt'), ('L1PA2', 'chr18_GL383570v1_alt'), ('L1HS', 'chr18_GL383570v1_alt'), ('L1HS', 'chr20_GL383577v2_alt'), ('L1HS', 'chr21_GL383579v2_alt'), ('L1HS', 'chr14_KI270725v1_random')]
ORF1_list = [('L1PA2', 'chr1'), ('L1PA4', 'chr1'), ('L1PA2', 'chr1'), ('L1PA4', 'chr1'), ('L1PA8', 'chr1'), ('L1HS', 'chr1'), ('L1PA4', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1PA4', 'chr1'), ('L1PA4', 'chr1'), ('L1PA4', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA5', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA4', 'chr1'), ('L1HS', 'chr1'), ('L1PA3', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA5', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1PA3', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA7', 'chr1'), ('L1PA3', 'chr1'), ('L1PA3', 'chr1'), ('L1HS', 'chr1'), ('L1PA4', 'chr1'), ('L1PA6', 'chr1'), ('L1HS', 'chr1'), ('L1PA5', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1PA3', 'chr1'), ('L1PA2', 'chr1'), ('L1P1', 'chr1'), ('L1PA6', 'chr1'), ('L1PA2', 'chr1'), ('L1P1', 'chr1'), ('L1HS', 'chr1'), ('L1PA5', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1PA5', 'chr1'), ('L1PA5', 'chr1'), ('L1HS', 'chr1'), ('L1PA7', 'chr1'), ('L1PA2', 'chr1'), ('L1PA4', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA3', 'chr1'), ('L1HS', 'chr1'), ('L1PA3', 'chr1'), ('L1PA4', 'chr1'), ('L1HS', 'chr1'), ('L1PA3', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA11', 'chr1'), ('L1PA4', 'chr1'), ('L1PA5', 'chr1'), ('L1HS', 'chr1'), ('L1PA5', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA5', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1P1', 'chr2'), ('L1PA6', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA5', 'chr2'), ('L1PA3', 'chr2'), ('L1PA4', 'chr2'), ('L1PA4', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA4', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA5', 'chr2'), ('L1PA3', 'chr2'), ('L1PA4', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA6', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA4', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA4', 'chr2'), ('L1PA4', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA6', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1PA4', 'chr2'), ('L1PA5', 'chr2'), ('L1PA4', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA5', 'chr2'), ('L1PA2', 'chr2'), ('L1PA5', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA5', 'chr2'), ('L1PA2', 'chr2'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1PA5', 'chr3'), ('L1PA2', 'chr3'), ('L1PA6', 'chr3'), ('L1HS', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA4', 'chr3'), ('L1PA3', 'chr3'), ('L1PA5', 'chr3'), ('L1PA5', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA7', 'chr3'), ('L1PA4', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA7', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1PA5', 'chr3'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA4', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA5', 'chr3'), ('L1PA5', 'chr3'), ('L1PA5', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA5', 'chr3'), ('L1PA4', 'chr3'), ('L1PA6', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA4', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA4', 'chr3'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr3'), ('L1PA4', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA3', 'chr3'), ('L1PA4', 'chr3'), ('L1PA3', 'chr3'), ('L1PA5', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr4'), ('L1PA4', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA6', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA4', 'chr4'), ('L1PA2', 'chr4'), ('L1PA6', 'chr4'), ('L1PA7', 'chr4'), ('L1PA4', 'chr4'), ('L1P1', 'chr4'), ('L1PA3', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1PA4', 'chr4'), ('L1PA3', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA4', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1P2', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA6', 'chr4'), ('L1HS', 'chr4'), ('L1PA5', 'chr4'), ('L1PA3', 'chr4'), ('L1PA4', 'chr4'), ('L1PA5', 'chr4'), ('L1HS', 'chr4'), ('L1PA5', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA5', 'chr4'), ('L1HS', 'chr4'), ('L1PA4', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1PA4', 'chr4'), ('L1PA5', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1PA3', 'chr4'), ('L1PA3', 'chr4'), ('L1PA4', 'chr4'), ('L1PA5', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA4', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1PA7', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1PA3', 'chr4'), ('L1PA2', 'chr4'), ('L1PA3', 'chr4'), ('L1PA4', 'chr4'), ('L1PA4', 'chr5'), ('L1PA3', 'chr5'), ('L1PA7', 'chr5'), ('L1HS', 'chr5'), ('L1PA4', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA5', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA4', 'chr5'), ('L1PA6', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA3', 'chr5'), ('L1PA5', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA7', 'chr5'), ('L1PA7', 'chr5'), ('L1PA4', 'chr5'), ('L1PA7', 'chr5'), ('L1PA3', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA5', 'chr5'), ('L1PA2', 'chr5'), ('L1PA4', 'chr5'), ('L1PB1', 'chr5'), ('L1PA2', 'chr5'), ('L1PA3', 'chr5'), ('L1PA3', 'chr5'), ('L1PA5', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA4', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA4', 'chr5'), ('L1HS', 'chr5'), ('L1PA6', 'chr5'), ('L1PA3', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1PA4', 'chr5'), ('L1PA3', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1PA5', 'chr5'), ('L1PA3', 'chr5'), ('L1PA3', 'chr5'), ('L1PA6', 'chr5'), ('L1PA5', 'chr5'), ('L1PA6', 'chr5'), ('L1PA4', 'chr5'), ('L1PA4', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA4', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1PA5', 'chr5'), ('L1PA3', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA6', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1HS', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA6', 'chr6'), ('L1PA7', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1PA4', 'chr6'), ('L1PA5', 'chr6'), ('L1PA4', 'chr6'), ('L1PA4', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA6', 'chr6'), ('L1HS', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA4', 'chr6'), ('L1PA3', 'chr6'), ('L1PA4', 'chr6'), ('L1PA4', 'chr6'), ('L1PA3', 'chr6'), ('L1PA6', 'chr6'), ('L1P1', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1PA4', 'chr6'), ('L1HS', 'chr6'), ('L1PA5', 'chr6'), ('L1PA3', 'chr6'), ('L1PA5', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA4', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA6', 'chr6'), ('L1PA2', 'chr6'), ('L1PA6', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA4', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA4', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1HS', 'chr6'), ('L1PA4', 'chr6'), ('L1PA3', 'chr6'), ('L1PA4', 'chr6'), ('L1PA4', 'chr6'), ('L1HS', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA5', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr7'), ('L1PA2', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1PA4', 'chr7'), ('L1PA11', 'chr7'), ('L1PA3', 'chr7'), ('L1PA2', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA6', 'chr7'), ('L1PA3', 'chr7'), ('L1PA3', 'chr7'), ('L1PA3', 'chr7'), ('L1PA4', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA4', 'chr7'), ('L1PA4', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA3', 'chr7'), ('L1PA2', 'chr7'), ('L1PA4', 'chr7'), ('L1PA2', 'chr7'), ('L1PA3', 'chr7'), ('L1PA3', 'chr7'), ('L1PA3', 'chr7'), ('L1PA2', 'chr7'), ('L1P1', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1PA5', 'chr7'), ('L1PA4', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1PA5', 'chr7'), ('L1PA4', 'chr7'), ('L1PA2', 'chr7'), ('L1PA4', 'chr7'), ('L1PA2', 'chr7'), ('L1PA2', 'chr7'), ('L1PA4', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1PA4', 'chr7'), ('L1PA3', 'chr7'), ('L1HS', 'chr7'), ('L1PA5', 'chr7'), ('L1PA4', 'chr8'), ('L1HS', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA4', 'chr8'), ('L1PA4', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA4', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA6', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA4', 'chr8'), ('L1PA4', 'chr8'), ('L1PA7', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA3', 'chr8'), ('L1PA6', 'chr8'), ('L1PA7', 'chr8'), ('L1PA4', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA4', 'chr8'), ('L1PA3', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA5', 'chr8'), ('L1PA2', 'chr8'), ('L1PA5', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1P1', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA6', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA3', 'chr8'), ('L1PA3', 'chr8'), ('L1PA4', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA3', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA3', 'chr8'), ('L1PA2', 'chr9'), ('L1PA4', 'chr9'), ('L1PA2', 'chr9'), ('L1PA3', 'chr9'), ('L1PA3', 'chr9'), ('L1PA7', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA4', 'chr9'), ('L1HS', 'chr9'), ('L1PA3', 'chr9'), ('L1PA2', 'chr9'), ('L1PA3', 'chr9'), ('L1HS', 'chr9'), ('L1PA2', 'chr9'), ('L1PA3', 'chr9'), ('L1P1', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA6', 'chr9'), ('L1HS', 'chr9'), ('L1PA2', 'chr9'), ('L1PA3', 'chr9'), ('L1HS', 'chr9'), ('L1PA4', 'chr9'), ('L1PA2', 'chr9'), ('L1PA3', 'chr9'), ('L1HS', 'chr9'), ('L1PA3', 'chr9'), ('L1HS', 'chr9'), ('L1PA6', 'chr9'), ('L1HS', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA4', 'chr9'), ('L1PA5', 'chr9'), ('L1PA5', 'chr9'), ('L1PA2', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chr9'), ('L1PA7', 'chr9'), ('L1PA2', 'chr9'), ('L1PA2', 'chr9'), ('L1PA5', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA4', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA15', 'chrX'), ('L1PA4', 'chrX'), ('L1HS', 'chrX'), ('L1PA6', 'chrX'), ('L1PA3', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1PA4', 'chrX'), ('L1PA4', 'chrX'), ('L1PA2', 'chrX'), ('L1PA5', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1P1', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA4', 'chrX'), ('L1HS', 'chrX'), ('L1PA4', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA4', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA5', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA5', 'chrX'), ('L1PA4', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA6', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1PA7', 'chrX'), ('L1PA6', 'chrX'), ('L1PA5', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA5', 'chrX'), ('L1PA4', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA6', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrY'), ('L1HS', 'chrY'), ('L1PA3', 'chrY'), ('L1PA3', 'chrY'), ('L1PA5', 'chrY'), ('L1HS', 'chrY'), ('L1PA3', 'chrY'), ('L1PA2', 'chrY'), ('L1PA3', 'chrY'), ('L1PA3', 'chrY'), ('L1PA3', 'chrY'), ('L1PA4', 'chrY'), ('L1PA3', 'chrY'), ('L1PA2', 'chrY'), ('L1PA5', 'chrY'), ('L1PA4', 'chrY'), ('L1PA2', 'chrY'), ('L1PA3', 'chrY'), ('L1PA3', 'chrY'), ('L1PA6', 'chr10'), ('L1PA2', 'chr10'), ('L1PA4', 'chr10'), ('L1HS', 'chr10'), ('L1PA3', 'chr10'), ('L1HS', 'chr10'), ('L1PA3', 'chr10'), ('L1PA4', 'chr10'), ('L1PA2', 'chr10'), ('L1PA4', 'chr10'), ('L1PA2', 'chr10'), ('L1PA3', 'chr10'), ('L1PA3', 'chr10'), ('L1HS', 'chr10'), ('L1PA3', 'chr10'), ('L1HS', 'chr10'), ('L1PA3', 'chr10'), ('L1PA6', 'chr10'), ('L1PA5', 'chr10'), ('L1PA6', 'chr10'), ('L1PA3', 'chr10'), ('L1PA3', 'chr10'), ('L1PA3', 'chr10'), ('L1PA4', 'chr10'), ('L1PA3', 'chr10'), ('L1PA5', 'chr10'), ('L1PA4', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr10'), ('L1PA3', 'chr10'), ('L1PA2', 'chr10'), ('L1PA3', 'chr10'), ('L1HS', 'chr10'), ('L1PA3', 'chr10'), ('L1PA4', 'chr10'), ('L1PA3', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1PA3', 'chr10'), ('L1PA2', 'chr10'), ('L1PA3', 'chr10'), ('L1PA3', 'chr10'), ('L1PA5', 'chr10'), ('L1PA3', 'chr10'), ('L1PA3', 'chr10'), ('L1PA5', 'chr10'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA3', 'chr11'), ('L1PA4', 'chr11'), ('L1PA2', 'chr11'), ('L1PA6', 'chr11'), ('L1PA3', 'chr11'), ('L1PA7', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1P1', 'chr11'), ('L1PA3', 'chr11'), ('L1PA5', 'chr11'), ('L1PA3', 'chr11'), ('L1HS', 'chr11'), ('L1PA5', 'chr11'), ('L1PA3', 'chr11'), ('L1PA3', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1PA3', 'chr11'), ('L1PA5', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1PA5', 'chr11'), ('L1PA4', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA4', 'chr11'), ('L1HS', 'chr11'), ('L1PA3', 'chr11'), ('L1PA2', 'chr11'), ('L1PA3', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1PA2', 'chr11'), ('L1PA2', 'chr11'), ('L1PA3', 'chr11'), ('L1PA2', 'chr11'), ('L1HS', 'chr11'), ('L1PA5', 'chr11'), ('L1HS', 'chr12'), ('L1PA5', 'chr12'), ('L1PA5', 'chr12'), ('L1PA3', 'chr12'), ('L1PA3', 'chr12'), ('L1P1', 'chr12'), ('L1PA4', 'chr12'), ('L1PA2', 'chr12'), ('L1PA3', 'chr12'), ('L1PA4', 'chr12'), ('L1PA4', 'chr12'), ('L1PA4', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1PA3', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA4', 'chr12'), ('L1PA2', 'chr12'), ('L1PA7', 'chr12'), ('L1PA2', 'chr12'), ('L1PA3', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr12'), ('L1PA3', 'chr12'), ('L1PA3', 'chr12'), ('L1PA2', 'chr12'), ('L1PA3', 'chr12'), ('L1PA3', 'chr12'), ('L1PA2', 'chr12'), ('L1PA3', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1HS', 'chr12'), ('L1PA2', 'chr13'), ('L1PA5', 'chr13'), ('L1PA4', 'chr13'), ('L1HS', 'chr13'), ('L1HS', 'chr13'), ('L1PA5', 'chr13'), ('L1PA4', 'chr13'), ('L1PA2', 'chr13'), ('L1PA5', 'chr13'), ('L1PA2', 'chr13'), ('L1PA2', 'chr13'), ('L1PA4', 'chr13'), ('L1PA2', 'chr13'), ('L1P1', 'chr13'), ('L1PA3', 'chr13'), ('L1PA4', 'chr13'), ('L1PA2', 'chr13'), ('L1PA3', 'chr13'), ('L1PA2', 'chr13'), ('L1PA3', 'chr13'), ('L1PA3', 'chr13'), ('L1PA4', 'chr13'), ('L1PA3', 'chr13'), ('L1HS', 'chr13'), ('L1HS', 'chr14'), ('L1PA3', 'chr14'), ('L1PA5', 'chr14'), ('L1PA6', 'chr14'), ('L1PA5', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1HS', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1PA3', 'chr14'), ('L1PA2', 'chr14'), ('L1PA3', 'chr14'), ('L1PA4', 'chr14'), ('L1PA3', 'chr14'), ('L1HS', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr14'), ('L1PA4', 'chr14'), ('L1PA4', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1PA3', 'chr14'), ('L1PA3', 'chr14'), ('L1PA2', 'chr15'), ('L1PA5', 'chr15'), ('L1PA5', 'chr15'), ('L1PA4', 'chr15'), ('L1PA3', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1PA3', 'chr15'), ('L1PA2', 'chr15'), ('L1PA3', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1P1', 'chr15'), ('L1PA2', 'chr15'), ('L1PA6', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1PA5', 'chr15'), ('L1PA3', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1PA2', 'chr15'), ('L1PA5', 'chr15'), ('L1PA3', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1PA3', 'chr15'), ('L1PA4', 'chr15'), ('L1PA2', 'chr15'), ('L1PA3', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1PA6', 'chr16'), ('L1PA2', 'chr16'), ('L1PA2', 'chr16'), ('L1PA4', 'chr16'), ('L1HS', 'chr16'), ('L1P1', 'chr16'), ('L1PA2', 'chr16'), ('L1PA2', 'chr16'), ('L1PA2', 'chr16'), ('L1PA3', 'chr16'), ('L1PA2', 'chr16'), ('L1PA3', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1PA5', 'chr16'), ('L1HS', 'chr16'), ('L1PA3', 'chr16'), ('L1PA2', 'chr17'), ('L1PA5', 'chr17'), ('L1HS', 'chr17'), ('L1PA2', 'chr17'), ('L1PA2', 'chr17'), ('L1PA2', 'chr17'), ('L1PA2', 'chr17'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA4', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1PA4', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA4', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA5', 'chr18'), ('L1PA6', 'chr19'), ('L1PA5', 'chr19'), ('L1PA4', 'chr19'), ('L1PA3', 'chr19'), ('L1PA3', 'chr19'), ('L1PA3', 'chr19'), ('L1HS', 'chr19'), ('L1PA2', 'chr19'), ('L1HS', 'chr20'), ('L1PA2', 'chr20'), ('L1HS', 'chr20'), ('L1PA4', 'chr20'), ('L1PA2', 'chr20'), ('L1HS', 'chr20'), ('L1PA3', 'chr20'), ('L1PA3', 'chr20'), ('L1PA3', 'chr20'), ('L1PA4', 'chr20'), ('L1PA2', 'chr20'), ('L1PA4', 'chr20'), ('L1PA5', 'chr20'), ('L1HS', 'chr20'), ('L1PA3', 'chr21'), ('L1PA2', 'chr21'), ('L1PA5', 'chr21'), ('L1PA2', 'chr21'), ('L1PA2', 'chr21'), ('L1PA2', 'chr21'), ('L1HS', 'chr22'), ('L1PA6', 'chr22'), ('L1HS', 'chr22'), ('L1PA2', 'chr22'), ('L1HS', 'chr22'), ('L1PA3', 'chrUn_KI270743v1'), ('L1PA2', 'chr1_KI270760v1_alt'), ('L1HS', 'chr2_GL383521v1_alt'), ('L1HS', 'chr2_GL582966v2_alt'), ('L1PA3', 'chr2_KI270770v1_alt'), ('L1PA4', 'chr6_GL000250v2_alt'), ('L1PA4', 'chr6_GL000251v2_alt'), ('L1PA5', 'chr6_GL000251v2_alt'), ('L1PA4', 'chr6_GL000252v2_alt'), ('L1HS', 'chr6_GL000252v2_alt'), ('L1PA4', 'chr6_GL000253v2_alt'), ('L1HS', 'chr6_GL000253v2_alt'), ('L1PA5', 'chr6_GL000253v2_alt'), ('L1HS', 'chr6_GL000253v2_alt'), ('L1PA4', 'chr6_GL000256v2_alt'), ('L1PA5', 'chr6_GL000256v2_alt'), ('L1PA3', 'chr8_KI270810v1_alt'), ('L1PA6', 'chr8_KI270822v1_alt'), ('L1PA2', 'chr8_KI270900v1_alt'), ('L1PA2', 'chr8_KI270926v1_alt'), ('L1PA2', 'chr9_KI270823v1_alt'), ('L1HS', 'chr12_GL383549v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1PA3', 'chr14_KI270847v1_alt'), ('L1PA4', 'chr15_KI270905v1_alt'), ('L1HS', 'chr16_KI270853v1_alt'), ('L1HS', 'chr17_GL383565v1_alt'), ('L1HS', 'chr17_GL383565v1_alt'), ('L1HS', 'chr18_GL383567v1_alt'), ('L1PA5', 'chr18_GL383568v1_alt'), ('L1HS', 'chr18_GL383568v1_alt'), ('L1HS', 'chr18_GL383570v1_alt'), ('L1HS', 'chr20_GL383577v2_alt'), ('L1HS', 'chr21_GL383579v2_alt'), ('L1PA3', 'chr4_GL000008v2_random'), ('L1PA2', 'chr5_GL000208v1_random'), ('L1PA2', 'chr17_GL000205v2_random')]
ORF2_list = [('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1PA2', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1HS', 'chr1'), ('L1PA3', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA3', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr2'), ('L1PA2', 'chr2'), ('L1HS', 'chr2'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1HS', 'chr3'), ('L1PA3', 'chr3'), ('L1HS', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA2', 'chr3'), ('L1PA3', 'chr3'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1PA3', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr4'), ('L1PA2', 'chr4'), ('L1PA2', 'chr4'), ('L1HS', 'chr4'), ('L1HS', 'chr5'), ('L1PA3', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA2', 'chr5'), ('L1PA2', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1HS', 'chr5'), ('L1PA3', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr6'), ('L1PA3', 'chr6'), ('L1PA3', 'chr6'), ('L1PA2', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1HS', 'chr6'), ('L1PA2', 'chr6'), ('L1PA2', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr7'), ('L1HS', 'chr8'), ('L1PA3', 'chr8'), ('L1PA3', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr8'), ('L1HS', 'chr8'), ('L1PA2', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chr9'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1PA2', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1PA3', 'chrX'), ('L1PA2', 'chrX'), ('L1PA3', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrX'), ('L1HS', 'chrY'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1PA2', 'chr10'), ('L1PA2', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr10'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr11'), ('L1HS', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1PA2', 'chr12'), ('L1HS', 'chr12'), ('L1HS', 'chr13'), ('L1HS', 'chr13'), ('L1PA2', 'chr13'), ('L1PA2', 'chr14'), ('L1HS', 'chr14'), ('L1HS', 'chr14'), ('L1PA2', 'chr14'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr15'), ('L1PA2', 'chr15'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1PA2', 'chr16'), ('L1HS', 'chr16'), ('L1HS', 'chr17'), ('L1HS', 'chr17'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1PA3', 'chr18'), ('L1PA2', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1PA2', 'chr18'), ('L1HS', 'chr18'), ('L1HS', 'chr18'), ('L1PA3', 'chr19'), ('L1PA2', 'chr19'), ('L1PA2', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr20'), ('L1HS', 'chr22'), ('L1HS', 'chr22'), ('L1HS', 'chr2_GL383521v1_alt'), ('L1HS', 'chr2_GL582966v2_alt'), ('L1HS', 'chr6_GL000252v2_alt'), ('L1HS', 'chr6_GL000253v2_alt'), ('L1PA3', 'chr8_KI270821v1_alt'), ('L1PA2', 'chr8_KI270926v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1HS', 'chr12_GL383551v1_alt'), ('L1HS', 'chr16_KI270853v1_alt'), ('L1HS', 'chr17_GL383565v1_alt'), ('L1HS', 'chr18_GL383567v1_alt'), ('L1HS', 'chr18_GL383570v1_alt'), ('L1HS', 'chr20_GL383577v2_alt'), ('L1HS', 'chr21_GL383579v2_alt')]

#seperate the original lists into repNames and chromosomes
repNamelist_orf0 = []
chrlist_orf0 = []

chromosome_list=["chr1","chr2","chr3", "chr4", "chr5", "chr6", "chr7", "chr8", "chr9", "chr10", "chr11", "chr12", "chr13", "chr14", "chr15", "chr16", "chr17", "chr18", "chr19", "chr20", "chr21", "chr22", "chrX", "chrY"]
for i in ORF0_list:
    if i[1] in chromosome_list:
        repNamelist_orf0.append(i[0])
        chrlist_orf0.append(i[1])
        
#count the number of repNames that express ORF0 and make into a dictionary
t=Counter(repNamelist_orf0)
g1=dict(t)

g1.values()
g1.keys()

repNamelist_orf1=[]
chrlist_orf1=[]


for i in ORF1_list:
    if i[1] in chromosome_list:
        repNamelist_orf1.append(i[0])
        chrlist_orf1.append(i[1])

h=Counter(repNamelist_orf1)
h1=dict(h)



h1.values()
h1.keys()


repNamelist_orf2=[]
chrlist_orf2=[]

for i in ORF2_list:
    if i[1] in chromosome_list:
        repNamelist_orf2.append(i[0])
        chrlist_orf2.append(i[1])

v=Counter(repNamelist_orf2)

v1=dict(v)



v1.values()
v1.keys()


all_dicts=[g1, h1, v1]

super_dict_keys=[]           

for d in all_dicts:
    for x in d:
        if x not in super_dict_keys:
            super_dict_keys.append(x)

# %%
print(super_dict_keys)
# Out:
# ['L1PA2', 'L1HS', 'L1PA3', 'L1PA4', 'L1P1', 'L1PA6', 'L1PA7', 'L1PA8', 'L1PA5', 'L1PA11', 'L1P2', 'L1PB1', 'L1PA15']

# %%
# create super dictionary
super_dict=dict((x,[0]) for x in super_dict_keys)  # "empty dictionary"

# for each key in the dictionary add the values from g1, h1, v1 in that order, including zero values
for x in super_dict:
    for y in all_dicts:
        if x in y:
            (super_dict[x]).append(y[x])
        else:
            (super_dict[x]).append(0)
print(super_dict)
# Out:
# {'L1PA2': [0, 215, 331, 69], 'L1HS': [0, 246, 258, 133], 'L1PA3': [0, 22, 270, 15], 'L1PA4': [0, 7, 139, 0], 'L1P1': [0, 2, 14, 0], 'L1PA6': [0, 1, 39, 0], 'L1PA7': [0, 1, 18, 0], 'L1PA8': [0, 0, 1, 0], 'L1PA5': [0, 0, 82, 0], 'L1PA11': [0, 0, 2, 0], 'L1P2': [0, 0, 1, 0], 'L1PB1': [0, 0, 1, 0], 'L1PA15': [0, 0, 1, 0]}

# %%
#PLOTTING STACKED BAR PLOT
N=len(super_dict)

#create empty lists
c=[]
v=[]
#key and values in super_dict dictionary is sperated into two lists
for key, val in super_dict.items():
    c.append(key)
    v.append(val)

    v=np.array(v)

#plot stack bar plot
p1=plt.bar(range(len(c)), v[:,1])
p2=plt.bar(range(len(c)), v[:,2], bottom =v[:,1])
p3=plt.bar(range(len(c)), v[:,3], bottom=v[:,1]+v[:,2]) 
plt.xticks(range(len(c)), c, rotation=90)
plt.legend((p1[0],p2[0],p3[0]), ('ORF0', 'ORF1', 'ORF2'))
plt.show()
